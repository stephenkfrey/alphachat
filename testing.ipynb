# %%
import fitz

from extract import get_text_around_images

# %%
get_text_around_images("data/dl15.pdf")
# Out:
# YOYOYOO
# [1, 2, 3, 4]

# %%
# !pip install llama-index chromadb --quiet
# !pip install chromadb==0.4.17
# !pip install sentence-transformers
# !pip install pydantic==1.10.11
# !pip install open-clip-torch
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclassic 0.5.6 requires nbformat, which is not installed.
# notebook 6.5.4 requires nbformat, which is not installed.
# discord-py 1.7.3 requires aiohttp<3.8.0,>=3.6.0, but you have aiohttp 3.9.1 which is incompatible.
# scanline 0.0.1 requires openai==0.27.2, but you have openai 1.3.7 which is incompatible.
# Collecting chromadb==0.4.17
#   Obtaining dependency information for chromadb==0.4.17 from https://files.pythonhosted.org/packages/24/2a/5cad8436a39c45f9fb9a6a0662d6254039f90a5710cf82410b685bbb7c71/chromadb-0.4.17-py3-none-any.whl.metadata
#   Downloading chromadb-0.4.17-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: requests>=2.28 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.99.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (4.7.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (1.15.1)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-api>=1.2.0 from https://files.pythonhosted.org/packages/51/3a/945e6c21f405ac4ea526f91ee09cc1568c04e0c95d3392903e6984c8f0e0/opentelemetry_api-1.21.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.21.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-grpc>=1.2.0 from https://files.pythonhosted.org/packages/75/59/ec3e39fe164c61306998cdd3cd30a857c4da2f8d3141204a929e57668eee/opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-sdk>=1.2.0 from https://files.pythonhosted.org/packages/c3/08/ca8b1ef7a2fa3f1ea2f12770eca8976098066adb442b1da81fea3b370123/opentelemetry_sdk-1.21.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.21.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.13.3)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (7.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (6.0.1)
# Collecting grpcio>=1.58.0 (from chromadb==0.4.17)
#   Downloading grpcio-1.59.3.tar.gz (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 3.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb==0.4.17)
#   Obtaining dependency information for kubernetes>=28.1.0 from https://files.pythonhosted.org/packages/f5/6a/1f69c2d8b1ff03f8d8e10d801f4ac3016ed4c1b00aa9795732c6ec900bba/kubernetes-28.1.0-py2.py3-none-any.whl.metadata
#   Downloading kubernetes-28.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (6.0.1)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from chromadb==0.4.17) (1.25.2)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.4.17) (0.27.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.4.17) (2023.7.22)
# Requirement already satisfied: six>=1.9.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.4.17) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.4.17) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.4.17) (2.22.0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb==0.4.17)
#   Obtaining dependency information for websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 from https://files.pythonhosted.org/packages/c4/3c/1892ce394828c43d4f65248ebdee3854114266b75d1f5915cb211155ad7b/websocket_client-1.6.4-py3-none-any.whl.metadata
#   Downloading websocket_client-1.6.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb==0.4.17)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb==0.4.17)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: urllib3<2.0,>=1.24.2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.4.17) (1.26.15)
# Requirement already satisfied: coloredlogs in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.17) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.17) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.17) (23.1)
# Requirement already satisfied: protobuf in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.17) (4.23.4)
# Requirement already satisfied: sympy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.17) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.17) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.17) (6.8.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.17) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.17) (1.60.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.21.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-common==1.21.0 from https://files.pythonhosted.org/packages/2a/60/ec618caf8fd8a4ac50500565eb49038ec42b7b168df9a316494085a740a6/opentelemetry_exporter_otlp_proto_common-1.21.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_common-1.21.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.21.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-proto==1.21.0 from https://files.pythonhosted.org/packages/69/c2/d11b5fbf95adf68440ff4c953e2d8d027c9c62ece79b78372af95af590c9/opentelemetry_proto-1.21.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_proto-1.21.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.42b0 (from opentelemetry-sdk>=1.2.0->chromadb==0.4.17)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.42b0 from https://files.pythonhosted.org/packages/c3/0c/4c99cbe85b65fbba5a638cb7d913cb3acead3d83b4c47763be28d418bb95/opentelemetry_semantic_conventions-0.42b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.42b0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.4.17) (1.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests>=2.28->chromadb==0.4.17) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests>=2.28->chromadb==0.4.17) (3.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.4.17) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (0.20.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.17) (11.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb==0.4.17) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.17) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.17) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.17) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.4.17) (3.16.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.17) (3.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.17) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.17) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.17) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.17) (1.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.17) (0.4.8)
# Downloading chromadb-0.4.17-py3-none-any.whl (496 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.8/496.8 kB 3.9 MB/s eta 0:00:0000:0100:01m
# Downloading kubernetes-28.1.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.0 MB/s eta 0:00:0000:0100:01m
# Downloading opentelemetry_api-1.21.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 740.6 kB/s eta 0:00:00--:--
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.21.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.21.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_sdk-1.21.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 4.4 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.42b0-py3-none-any.whl (36 kB)
# Downloading websocket_client-1.6.4-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: grpcio
#   Building wheel for grpcio (setup.py) ... done
#   Created wheel for grpcio: filename=grpcio-1.59.3-cp310-cp310-macosx_10_10_x86_64.whl size=4335660 sha256=80b09f2520484832646f3a67c807522f864af1e18ca728efad29ff54a7a95551
#   Stored in directory: /Users/stephen/Library/Caches/pip/wheels/e3/77/a2/1b624c4f1c03d7d33b35fa4ef25b13e56c8ce3fa5fac0911fc
# Successfully built grpcio
# Installing collected packages: websocket-client, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, grpcio, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.4.10
#     Uninstalling chromadb-0.4.10:
#       Successfully uninstalled chromadb-0.4.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 2.5.0 requires nbformat>=5.3.0, which is not installed.
# nbclassic 0.5.6 requires nbformat, which is not installed.
# notebook 6.5.4 requires nbformat, which is not installed.
# Successfully installed chromadb-0.4.17 grpcio-1.59.3 kubernetes-28.1.0 oauthlib-3.2.2 opentelemetry-api-1.21.0 opentelemetry-exporter-otlp-proto-common-1.21.0 opentelemetry-exporter-otlp-proto-grpc-1.21.0 opentelemetry-proto-1.21.0 opentelemetry-sdk-1.21.0 opentelemetry-semantic-conventions-0.42b0 requests-oauthlib-1.3.1 websocket-client-1.6.4
# Collecting sentence-transformers
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Obtaining dependency information for transformers<5.0.0,>=4.6.0 from https://files.pythonhosted.org/packages/12/dd/f17b11a93a9ca27728e12512d167eb1281c151c4c6881d3ab59eb58f4127/transformers-4.35.2-py3-none-any.whl.metadata
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sentence-transformers) (4.66.1)
# Collecting torch>=1.6.0 (from sentence-transformers)
#   Obtaining dependency information for torch>=1.6.0 from https://files.pythonhosted.org/packages/a1/0c/57bd3fd19758cdc4bd92637cfea9fcb9b3f65e38199e20a3605231a898f7/torch-2.1.1-cp310-none-macosx_10_9_x86_64.whl.metadata
#   Downloading torch-2.1.1-cp310-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision (from sentence-transformers)
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/4b/f6/7049c63eb322c7a705610edf4e93c9d6435f861ec94e5639b1a0016ba678/torchvision-0.16.1-cp310-cp310-macosx_10_13_x86_64.whl.metadata
#   Downloading torchvision-0.16.1-cp310-cp310-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sentence-transformers) (1.25.2)
# Collecting scikit-learn (from sentence-transformers)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/0d/53/570b55a6e10b8694ac1e3024d2df5cd443f1b4ff6d28430845da8b9019b3/scikit_learn-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata
#   Downloading scikit_learn-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sentence-transformers) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Using cached sentencepiece-0.1.99-cp310-cp310-macosx_10_9_x86_64.whl (1.2 MB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sentence-transformers) (0.17.1)
# Requirement already satisfied: filelock in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.8.8)
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Obtaining dependency information for tokenizers<0.19,>=0.14 from https://files.pythonhosted.org/packages/eb/49/a1997df128eec8b833e12824be47cb32d4d82e4933409d2e4abb577818ad/tokenizers-0.15.0-cp310-cp310-macosx_10_7_x86_64.whl.metadata
#   Downloading tokenizers-0.15.0-cp310-cp310-macosx_10_7_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Obtaining dependency information for safetensors>=0.3.1 from https://files.pythonhosted.org/packages/7f/2c/c280c846e54317d695ab6030fa46268a149a8b835651b541d6c32023f05f/safetensors-0.4.1-cp310-cp310-macosx_10_7_x86_64.whl.metadata
#   Downloading safetensors-0.4.1-cp310-cp310-macosx_10_7_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: click in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence-transformers)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torchvision->sentence-transformers) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Downloading torch-2.1.1-cp310-none-macosx_10_9_x86_64.whl (147.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 MB 4.1 MB/s eta 0:00:00:00:0100:01
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 12.8 MB/s eta 0:00:0000:0100:01
# Downloading scikit_learn-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 12.3 MB/s eta 0:00:0000:010:01
# Downloading torchvision-0.16.1-cp310-cp310-macosx_10_13_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.0 MB/s eta 0:00:0000:010:01
# Downloading safetensors-0.4.1-cp310-cp310-macosx_10_7_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 10.3 MB/s eta 0:00:0000:01
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading tokenizers-0.15.0-cp310-cp310-macosx_10_7_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 11.0 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=e34d66eaa403c649bcfd8de1d523e2e603803520292407b6ef820e18425d7b17
#   Stored in directory: /Users/stephen/Library/Caches/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, threadpoolctl, safetensors, torch, scikit-learn, torchvision, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
# Successfully installed safetensors-0.4.1 scikit-learn-1.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 threadpoolctl-3.2.0 tokenizers-0.15.0 torch-2.1.1 torchvision-0.16.1 transformers-4.35.2
# Collecting pydantic==1.10.11
#   Obtaining dependency information for pydantic==1.10.11 from https://files.pythonhosted.org/packages/90/6c/ef2c34321f035197621171d5cf243aedc43db69148b07308d95ca27bc036/pydantic-1.10.11-cp310-cp310-macosx_10_9_x86_64.whl.metadata
#   Downloading pydantic-1.10.11-cp310-cp310-macosx_10_9_x86_64.whl.metadata (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from pydantic==1.10.11) (4.7.1)
# Downloading pydantic-1.10.11-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 2.4 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scanline 0.0.1 requires openai==0.27.2, but you have openai 1.3.7 which is incompatible.
# Successfully installed pydantic-1.10.11
# Collecting open-clip-torch
#   Obtaining dependency information for open-clip-torch from https://files.pythonhosted.org/packages/7c/7f/952fdffa17b15d0c7c51a730860fcf4f4982528ecc753b190dcd46cc944b/open_clip_torch-2.23.0-py3-none-any.whl.metadata
#   Downloading open_clip_torch-2.23.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (2.1.1)
# Requirement already satisfied: torchvision in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (0.16.1)
# Requirement already satisfied: regex in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (2023.8.8)
# Collecting ftfy (from open-clip-torch)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tqdm in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (4.66.1)
# Requirement already satisfied: huggingface-hub in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (0.17.1)
# Requirement already satisfied: sentencepiece in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from open-clip-torch) (4.23.4)
# Collecting timm (from open-clip-torch)
#   Obtaining dependency information for timm from https://files.pythonhosted.org/packages/01/a5/eeb717242343d9ca34e7de554a6c08d96a0cfc7005ece4f847b1753581a6/timm-0.9.12-py3-none-any.whl.metadata
#   Downloading timm-0.9.12-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torch>=1.9.0->open-clip-torch) (2023.6.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->open-clip-torch)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub->open-clip-torch) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub->open-clip-torch) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from huggingface-hub->open-clip-torch) (23.1)
# Requirement already satisfied: safetensors in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from timm->open-clip-torch) (0.4.1)
# Requirement already satisfied: numpy in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torchvision->open-clip-torch) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from torchvision->open-clip-torch) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from jinja2->torch>=1.9.0->open-clip-torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub->open-clip-torch) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub->open-clip-torch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub->open-clip-torch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from requests->huggingface-hub->open-clip-torch) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/Caskroom/miniconda/base/envs/aieng/lib/python3.10/site-packages (from sympy->torch>=1.9.0->open-clip-torch) (1.3.0)
# Downloading open_clip_torch-2.23.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.9 MB/s eta 0:00:0000:0100:01
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.3 MB/s eta 0:00:00
# Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.6 MB/s eta 0:00:00a 0:00:01
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, ftfy, timm, open-clip-torch
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
# Successfully installed ftfy-6.1.3 open-clip-torch-2.23.0 timm-0.9.12 wcwidth-0.2.12
